# %%
# %matplotlib inline

import pandas as pd

df = pd.read_csv('analysis1.csv')
df = df.set_index('genus')
df
# Out:
#                 occurrences
# genus
# Lathamus                  7
# Neophema                  6
# Numenius                  8
# Calidris                  7
# Pedionomus                5
# Aipysurus                 3
# Pseudophryne              2
# Acanthocladium            2
# Synemon                   4
# Calystegia                2
# Pterodroma                2
# Carcharias                6
# Bidyanus                  5
# Ordtrachia                2
# Galaxias                  3
# Anthochaera               6
# Elymus                    2
# Glyphis                   3
# Thymichthys               2
# Limosa                    7
# Miniopterus               2

# %%
ax = df.plot(figsize=(8,6), kind='barh')
ax.set_xlabel('occurrences')
ax.set_title('Australian species considered Critically Endangered in TWO or more areas')
ax

# %%
def f(x):
   return x
#val = interact(f, x=(2,5));
val = interactive(f, x=(1,5))
val.children
display(val)
val.kwargs
# Out:
# 1

# %%
# %matplotlib inline

import pandas as pd
from ipywidgets import interact, interactive
from IPython.display import display

df2 = pd.read_csv('analysis2.csv')
df2 = df2.set_index('scientific_name')

result = val.result
#df2[df2.occurrences.isin(result)]
if result > 1:
    df2 = df2[df2.occurrences == result]
    print(df2)
else:
    print(df2)
# Out:
#                                    occurrences
# scientific_name
# Pseudomys gouldii                            5
# Leporillus apicalis                          5
# Chaeropus ecaudatus                          5
# Bettongia penicillata penicillata            5
# Notomys longicaudatus                        4
# Conilurus albipes                            4
# Onychogalea lunata                           4
# Lagorchestes leporides                       4
# Macrotis leucura                             4
# Senecio georgianus                           4
# Bettongia gaimardi gaimardi                  4
# Bettongia lesueur graii                      4
# Notomys amplus                               3
# Perameles eremiana                           3
# Perameles bougainville fasciata              3
# Lagorchestes hirsutus hirsutus               3
# Notomys mordax                               2
# Caloprymnus campestris                       2
# Macropus greyi                               2
# Lagorchestes asomatus                        2
# Psephotus pulcherrimus                       2
# Caladenia brachyscapa                        2

# %%
ax2 = df2.plot(figsize=(8,6), kind='barh', color='r')
ax2.set_xlabel('occurrences')
ax2.set_ylabel('scientific name')
ax2.set_title('Australian species considered Extinct in TWO or more areas')
ax2
